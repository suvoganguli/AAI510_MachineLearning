# %% [markdown]
# # Airbnb Data Analysis for New York City
#
# ## Introduction
#
# Airbnb, an online marketplace for lodging, has transformed the way people travel and find accommodations. In major cities like New York City, Airbnb listings provide a wide variety of options for travelers, ranging from entire apartments and homes to private rooms in shared apartments. This flexibility has made Airbnb a popular choice among both tourists and business travelers.
#
# In this notebook, we will explore the Airbnb dataset for New York City. This dataset provides detailed information on listings available on Airbnb, including prices, locations, types of properties, and reviews. By analyzing this data, we can gain insights into the rental market in New York City, understand pricing strategies, identify popular neighborhoods, and much more.
#
# ## Dataset Description
#
# The dataset used in this analysis is obtained from [Inside Airbnb](http://insideairbnb.com/get-the-data.html), a website that provides publicly available data on Airbnb listings. The New York City dataset contains various attributes for each listing, including:
#
# - **Listing ID**: A unique identifier for each Airbnb listing.
# - **Name**: The name of the listing.
# - **Host ID**: A unique identifier for the host.
# - **Host Name**: The name of the host.
# - **Neighborhood Group**: The general area or borough where the listing is located (e.g., Manhattan, Brooklyn).
# - **Neighborhood**: The specific neighborhood within the borough.
# - **Latitude**: The latitude coordinate of the listing.
# - **Longitude**: The longitude coordinate of the listing.
# - **Room Type**: The type of room being offered (e.g., entire home/apt, private room, shared room).
# - **Price**: The price per night for the listing.
# - **Minimum Nights**: The minimum number of nights a guest must stay.
# - **Number of Reviews**: The total number of reviews for the listing.
# - **Last Review**: The date of the last review.
# - **Reviews per Month**: The average number of reviews per month.
# - **Calculated Host Listings Count**: The total number of listings by the host.
# - **Availability 365**: The number of days the listing is available in a year.
#
# ## Objectives
#
# In this analysis, we aim to achieve the following objectives:
#
# 1. **Data Exploration**: Understand the structure and contents of the dataset through summary statistics and visualizations.
# 2. **Price Analysis**: Analyze the pricing strategies of different types of listings and identify factors influencing prices.
# 3. **Geographical Analysis**: Examine the geographical distribution of listings and identify popular neighborhoods.
# 4. **Review Analysis**: Investigate the review patterns and their correlation with listing popularity and price.
# 5. **Availability Analysis**: Analyze the availability of listings and identify trends related to booking frequency.

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read data

df = pd.read_csv("data/listings.csv")
df.head()
# Out:
#      id                                               name  host_id  \
# 0  5121                                    BlissArtsSpace!     7356
# 1  5136   Quiet Family Friendly Duplex w/ Patio + Backyard     7378
# 2  6848                   Only 2 stops to Manhattan studio    15991
# 3  6872  Uptown Sanctuary w/ Private Bath (Month to Month)    16104
# 4  6990                            UES Beautiful Blue Room    16800
#
#        host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0          Garon            Brooklyn  Bedford-Stuyvesant  40.68535  -73.95512
# 1        Rebecca            Brooklyn         Sunset Park  40.66265  -73.99454
# 2  Allen & Irina            Brooklyn        Williamsburg  40.70935  -73.95342
# 3            Kae           Manhattan         East Harlem  40.80107  -73.94255
# 4            Cyn           Manhattan         East Harlem  40.78778  -73.94759
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room   72.0              30                 50  2019-12-02
# 1  Entire home/apt  253.0              30                  4  2023-08-20
# 2  Entire home/apt   81.0              30                192  2024-01-08
# 3     Private room   65.0              30                  1  2022-06-05
# 4     Private room   60.0              30                247  2024-03-06
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.28                               2               233
# 1               0.03                               1                47
# 2               1.06                               1               164
# 3               0.04                               2               365
# 4               1.40                               1               179
#
#    number_of_reviews_ltm license
# 0                      0     NaN
# 1                      1     NaN
# 2                      3     NaN
# 3                      0     NaN
# 4                      3     NaN

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38377 entries, 0 to 38376
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              38377 non-null  int64
#  1   name                            38375 non-null  object
#  2   host_id                         38377 non-null  int64
#  3   host_name                       38372 non-null  object
#  4   neighbourhood_group             38377 non-null  object
#  5   neighbourhood                   38377 non-null  object
#  6   latitude                        38377 non-null  float64
#  7   longitude                       38377 non-null  float64
#  8   room_type                       38377 non-null  object
#  9   price                           23761 non-null  float64
#  10  minimum_nights                  38377 non-null  int64
#  11  number_of_reviews               38377 non-null  int64
#  12  last_review                     26766 non-null  object
#  13  reviews_per_month               26766 non-null  float64
#  14  calculated_host_listings_count  38377 non-null  int64
#  15  availability_365                38377 non-null  int64
#  16  number_of_reviews_ltm           38377 non-null  int64
#  17  license                         5063 non-null   object
# dtypes: float64(4), int64(7), object(7)
# memory usage: 5.3+ MB
# None

# %% [markdown]
# # Exploratory Data Analysis

# %%
# Remove the 'last_review' column
df.drop(columns=['last_review'], inplace=True)
df.drop(columns=['license'], inplace=True)
df.drop(columns=['host_id'], inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38377 entries, 0 to 38376
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              38377 non-null  int64
#  1   name                            38375 non-null  object
#  2   host_name                       38372 non-null  object
#  3   neighbourhood_group             38377 non-null  object
#  4   neighbourhood                   38377 non-null  object
#  5   latitude                        38377 non-null  float64
#  6   longitude                       38377 non-null  float64
#  7   room_type                       38377 non-null  object
#  8   price                           23761 non-null  float64
#  9   minimum_nights                  38377 non-null  int64
#  10  number_of_reviews               38377 non-null  int64
#  11  reviews_per_month               26766 non-null  float64
#  12  calculated_host_listings_count  38377 non-null  int64
#  13  availability_365                38377 non-null  int64
#  14  number_of_reviews_ltm           38377 non-null  int64
# dtypes: float64(4), int64(6), object(5)
# memory usage: 4.4+ MB

# %%
import missingno as msno

# Check for missing values
print("Missing values per column before cleaning:")
print(df.isnull().sum())

print('Shape of data before cleaning')
print(df.shape)

print('Number of unique neighborhoods before cleaning')
print(df['neighbourhood'].nunique())

# Visualize missing data
plt.figure(figsize=(12, 6))
msno.matrix(df)
plt.show()

# Visualize the missing data as a heatmap
plt.figure(figsize=(12, 6))
msno.heatmap(df, cmap='coolwarm')
plt.show()
# Out:
# Missing values per column before cleaning:
# id                                    0
# name                                  2
# host_name                             5
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                             14616
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 11611
# calculated_host_listings_count        0
# availability_365                      0
# number_of_reviews_ltm                 0
# dtype: int64
# Shape of data before cleaning
# (38377, 15)
# Number of unique neighborhoods before cleaning
# 225

# %% [markdown]
# ## Removing rows with missing data
#
# Find which neighborhoods are removed from the data after cleaning and add back those rows with the mean value

# %%
# Clean up whitespace or empty strings
df.replace(r'^\s*$', np.nan, regex=True, inplace=True)

# Store the original unique neighborhoods
original_neighbourhoods = df['neighbourhood'].unique()

# Remove rows with any missing data
df_cleaned = df.dropna()

# Check for missing values after dropping rows with missing data
print("Missing values per column after cleaning:")
print(df_cleaned.isnull().sum())

print('Shape of data after cleaning:')
print(df_cleaned.shape)

print('Number of unique neighborhoods after cleaning:')
print(df_cleaned['neighbourhood'].nunique())

# Verify there are no more missing values with matrix plot
plt.figure(figsize=(12, 6))
msno.matrix(df_cleaned)
plt.show()

# Find which neighborhoods were removed
cleaned_neighbourhoods = df_cleaned['neighbourhood'].unique()
removed_neighbourhoods = set(original_neighbourhoods) - set(cleaned_neighbourhoods)
print(f"Removed neighborhoods: {removed_neighbourhoods}")

# Calculate mean values for numerical columns in the cleaned dataset
mean_values = df_cleaned.mean(numeric_only=True)

# Create a DataFrame for the removed neighborhoods with mean values
rows_to_add = []
for neighborhood in removed_neighbourhoods:
    mean_row = mean_values.copy()
    mean_row['neighbourhood'] = neighborhood
    rows_to_add.append(mean_row)

# Convert the list of Series to a DataFrame
mean_rows_df = pd.DataFrame(rows_to_add)

# Append the new rows to the cleaned DataFrame
df_cleaned = pd.concat([df_cleaned, mean_rows_df], ignore_index=True)

# Verify the updated dataset
print("Data after adding back removed neighborhoods:")
print(df_cleaned.head())
print("Missing values per column after adding back removed neighborhoods:")
print(df_cleaned.isnull().sum())

# Display the first few rows after adding back the neighborhoods
print(df_cleaned.head())

# Verify the total number of unique neighborhoods
print(f"Total number of unique neighborhoods after adding back: {df_cleaned['neighbourhood'].nunique()}")

# Updating df with df_cleaned
df = df_cleaned
# Out:
# Missing values per column after cleaning:
# id                                0
# name                              0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# dtype: int64
# Shape of data after cleaning:
# (16947, 15)
# Number of unique neighborhoods after cleaning:
# 219
# Removed neighborhoods: {'Rossville', 'Fort Wadsworth', 'New Dorp', 'Dongan Hills', 'Hollis Hills', 'Oakwood'}
# Data after adding back removed neighborhoods:
#        id                                               name      host_name  \
# 0  5121.0                                    BlissArtsSpace!          Garon
# 1  5136.0   Quiet Family Friendly Duplex w/ Patio + Backyard        Rebecca
# 2  6848.0                   Only 2 stops to Manhattan studio  Allen & Irina
# 3  6872.0  Uptown Sanctuary w/ Private Bath (Month to Month)            Kae
# 4  6990.0                            UES Beautiful Blue Room            Cyn
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0            Brooklyn  Bedford-Stuyvesant  40.68535  -73.95512
# 1            Brooklyn         Sunset Park  40.66265  -73.99454
# 2            Brooklyn        Williamsburg  40.70935  -73.95342
# 3           Manhattan         East Harlem  40.80107  -73.94255
# 4           Manhattan         East Harlem  40.78778  -73.94759
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room   72.0            30.0               50.0
# 1  Entire home/apt  253.0            30.0                4.0
# 2  Entire home/apt   81.0            30.0              192.0
# 3     Private room   65.0            30.0                1.0
# 4     Private room   60.0            30.0              247.0
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.28                             2.0             233.0
# 1               0.03                             1.0              47.0
# 2               1.06                             1.0             164.0
# 3               0.04                             2.0             365.0
# 4               1.40                             1.0             179.0
#
#    number_of_reviews_ltm
# 0                    0.0
# 1                    1.0
# 2                    3.0
# 3                    0.0
# 4                    3.0
# Missing values per column after adding back removed neighborhoods:
# id                                0
# name                              6
# host_name                         6
# neighbourhood_group               6
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         6
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# dtype: int64
#        id                                               name      host_name  \
# 0  5121.0                                    BlissArtsSpace!          Garon
# 1  5136.0   Quiet Family Friendly Duplex w/ Patio + Backyard        Rebecca
# 2  6848.0                   Only 2 stops to Manhattan studio  Allen & Irina
# 3  6872.0  Uptown Sanctuary w/ Private Bath (Month to Month)            Kae
# 4  6990.0                            UES Beautiful Blue Room            Cyn
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0            Brooklyn  Bedford-Stuyvesant  40.68535  -73.95512
# 1            Brooklyn         Sunset Park  40.66265  -73.99454
# 2            Brooklyn        Williamsburg  40.70935  -73.95342
# 3           Manhattan         East Harlem  40.80107  -73.94255
# 4           Manhattan         East Harlem  40.78778  -73.94759
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room   72.0            30.0               50.0
# 1  Entire home/apt  253.0            30.0                4.0
# 2  Entire home/apt   81.0            30.0              192.0
# 3     Private room   65.0            30.0                1.0
# 4     Private room   60.0            30.0              247.0
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.28                             2.0             233.0
# 1               0.03                             1.0              47.0
# 2               1.06                             1.0             164.0
# 3               0.04                             2.0             365.0
# 4               1.40                             1.0             179.0
#
#    number_of_reviews_ltm
# 0                    0.0
# 1                    1.0
# 2                    3.0
# 3                    0.0
# 4                    3.0
# Total number of unique neighborhoods after adding back: 225

# %%
# Set styles for the plots
sns.set(style="whitegrid")
plt.style.use("fivethirtyeight")

# Histogram for price
plt.figure(figsize=(10, 6))
sns.histplot(df['price'])
plt.title('Distribution of Airbnb Prices in NYC')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.xlim(0, df['price'].quantile(0.99))  # To limit the x-axis to the 99th percentile to avoid extreme outliers
plt.show()

# %%
# Split the data into two groups
df_below_1000 = df[df['price'] <= 1000]
df_above_1000 = df[df['price'] > 1000]

# Plot the data
plt.figure(figsize=(12, 8))

# Scatter plot for prices <= 1000
sc = plt.scatter(df_below_1000['longitude'], df_below_1000['latitude'], c=df_below_1000['price'], cmap='viridis', alpha=0.5, label='Price <= 1000')

# Scatter plot for prices > 1000
plt.scatter(df_above_1000['longitude'], df_above_1000['latitude'], color='red', alpha=0.5, label='Price > 1000')

# Add color bar for the price <= 1000 points
cbar = plt.colorbar(sc, label='Price (<= 1000)')

# Add titles and labels
plt.title('Airbnb Prices in NYC')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()
plt.show()

# %% [markdown]
# The plot above shows the scatter plot of the price vs latitude-longitude. The prices above $1000 are marked by red.

# %%
import matplotlib.cm as cm

# Count the occurrences of each room type
room_type_counts = df['room_type'].value_counts()

# Get the viridis colormap
cmap = cm.get_cmap('viridis')

# Normalize the color range
norm = plt.Normalize(room_type_counts.min(), room_type_counts.max())
colors = cmap(norm(room_type_counts.values))

# Plot the counts
plt.figure(figsize=(10, 6))
plt.bar(room_type_counts.index, room_type_counts.values, color=colors)

# Add titles and labels
plt.title('Count of Room Types in Airbnb Listings')
plt.xlabel('Room Type')
plt.ylabel('Count')

# Add value labels on the bars
for index, value in enumerate(room_type_counts.values):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.show()
# Out:
# /var/folders/d7/3y4pn1x55_583bts49jyqlxh0000gn/T/ipykernel_10671/755991337.py:7: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = cm.get_cmap('viridis')

# %%
# Count the occurrences of each neighborhood group
neighborhood_group_counts = df['neighbourhood_group'].value_counts()

# Plot the counts
plt.figure(figsize=(10, 6))
plt.bar(neighborhood_group_counts.index, neighborhood_group_counts.values, color='skyblue')

# Add titles and labels
plt.title('Count of Neighborhood Groups in Airbnb Listings')
plt.xlabel('Neighborhood Group')
plt.ylabel('Count')

# Add value labels on the bars
for index, value in enumerate(neighborhood_group_counts.values):
    plt.text(index, value, str(value), ha='center', va='bottom')

plt.show()

# %%
# Plot the histogram for availability_365
plt.figure(figsize=(10, 6))
plt.hist(df['availability_365'], bins=30, edgecolor='black', color='skyblue')

# Add titles and labels
plt.title('Histogram of Availability (365 days) in Airbnb Listings')
plt.xlabel('Availability in 365 days')
plt.ylabel('Frequency')

plt.show()

# %%
df.describe()
# Out:
#                  id      latitude     longitude          price  \
# count  1.695300e+04  16953.000000  16953.000000   16953.000000
# mean   3.462485e+17     40.725360    -73.939236     195.934679
# std    4.123269e+17      0.060747      0.061693     807.439364
# min    5.121000e+03     40.500314    -74.249840      10.000000
# 25%    2.778567e+07     40.682660    -73.980950      85.000000
# 50%    5.162274e+07     40.721000    -73.949350     135.000000
# 75%    7.656736e+17     40.763430    -73.917430     218.000000
# max    1.126177e+18     40.911147    -73.713650  100000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    16953.000000       16953.000000       16953.000000
# mean        26.016345          46.419543           1.278998
# std         21.491447          79.738091           2.054920
# min          1.000000           1.000000           0.010000
# 25%         30.000000           4.000000           0.230000
# 50%         30.000000          16.000000           0.690000
# 75%         30.000000          54.000000           1.800000
# max        730.000000        1901.000000          91.220000
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# count                    16953.000000      16953.000000           16953.000000
# mean                        21.552015        224.236915              10.928247
# std                         88.052226        113.432746              23.008294
# min                          1.000000          0.000000               0.000000
# 25%                          1.000000        121.000000               1.000000
# 50%                          2.000000        240.000000               4.000000
# 75%                          6.000000        339.000000              15.000000
# max                        866.000000        365.000000            1123.000000

# %% [markdown]
# # Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Identify categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
print(f"Categorical columns: {categorical_columns}")

# Encode categorical variables
df = pd.get_dummies(df, columns=categorical_columns, drop_first=True)

# Ensure all data is numeric
print(df.dtypes)

# Define features and target
X = df.drop('price', axis=1)
y = df['price']

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
# Out:
# Categorical columns: ['name', 'host_name', 'neighbourhood_group', 'neighbourhood', 'room_type']
# id                        float64
# latitude                  float64
# longitude                 float64
# price                     float64
# minimum_nights            float64
#                            ...
# neighbourhood_Woodrow       uint8
# neighbourhood_Woodside      uint8
# room_type_Hotel room        uint8
# room_type_Private room      uint8
# room_type_Shared room       uint8
# Length: 21840, dtype: object

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV

# Hyperparameter tuning using GridSearchCV
param_grid = {
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 10],
    'min_samples_leaf': [1, 5]
}

grid_search = GridSearchCV(
    DecisionTreeRegressor(random_state=42),
    param_grid,
    cv=5,
    scoring='r2',
    verbose=3  # Set verbosity to show progress
)
grid_search.fit(X_train, y_train)

# Best parameters
best_params = grid_search.best_params_
print(f"Best parameters: {best_params}")

# Train model with best parameters
model = DecisionTreeRegressor(**best_params, random_state=42)
model.fit(X_train, y_train)  # Fit the model

# Make predictions
y_pred = model.predict(X_test)

# Evaluate model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'R-squared: {r2}')
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.056 total time=  44.4s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.095 total time=  37.6s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=-0.000 total time=  42.0s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.142 total time=  38.3s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=2;, score=0.165 total time=  36.9s
# [CV 1/5] END max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.103 total time=  37.3s
# [CV 2/5] END max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.124 total time=  35.7s
# [CV 3/5] END max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=-0.000 total time=  35.1s
# [CV 4/5] END max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.143 total time=  37.0s
# [CV 5/5] END max_depth=None, min_samples_leaf=1, min_samples_split=10;, score=0.158 total time=  36.0s
# [CV 1/5] END max_depth=None, min_samples_leaf=5, min_samples_split=2;, score=-1.599 total time=  14.6s
# [CV 2/5] END max_depth=None, min_samples_leaf=5, min_samples_split=2;, score=0.015 total time=  14.3s
# [CV 3/5] END max_depth=None, min_samples_leaf=5, min_samples_split=2;, score=-0.002 total time=  14.9s
# [CV 4/5] END max_depth=None, min_samples_leaf=5, min_samples_split=2;, score=0.047 total time=  15.6s
# [CV 5/5] END max_depth=None, min_samples_leaf=5, min_samples_split=2;, score=-6.682 total time=  15.4s
# [CV 1/5] END max_depth=None, min_samples_leaf=5, min_samples_split=10;, score=-1.599 total time=  14.5s
# [CV 2/5] END max_depth=None, min_samples_leaf=5, min_samples_split=10;, score=0.015 total time=  14.8s
# [CV 3/5] END max_depth=None, min_samples_leaf=5, min_samples_split=10;, score=-0.002 total time=  17.1s
# [CV 4/5] END max_depth=None, min_samples_leaf=5, min_samples_split=10;, score=0.047 total time=  16.2s
# [CV 5/5] END max_depth=None, min_samples_leaf=5, min_samples_split=10;, score=-6.682 total time=  15.4s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.080 total time=  22.8s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.134 total time=  24.3s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=-0.000 total time=  23.9s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.116 total time=  32.3s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=2;, score=0.116 total time=  29.4s
# [CV 1/5] END max_depth=10, min_samples_leaf=1, min_samples_split=10;, score=0.072 total time=  25.9s
# [CV 2/5] END max_depth=10, min_samples_leaf=1, min_samples_split=10;, score=0.136 total time=  23.7s
# [CV 3/5] END max_depth=10, min_samples_leaf=1, min_samples_split=10;, score=-0.000 total time=  23.5s
# [CV 4/5] END max_depth=10, min_samples_leaf=1, min_samples_split=10;, score=0.112 total time=  31.9s
# [CV 5/5] END max_depth=10, min_samples_leaf=1, min_samples_split=10;, score=0.121 total time=  23.9s
# [CV 1/5] END max_depth=10, min_samples_leaf=5, min_samples_split=2;, score=-1.513 total time=  13.7s
# [CV 2/5] END max_depth=10, min_samples_leaf=5, min_samples_split=2;, score=0.097 total time=  14.3s
# [CV 3/5] END max_depth=10, min_samples_leaf=5, min_samples_split=2;, score=-0.001 total time=  14.0s
# [CV 4/5] END max_depth=10, min_samples_leaf=5, min_samples_split=2;, score=0.110 total time=  14.4s
# [CV 5/5] END max_depth=10, min_samples_leaf=5, min_samples_split=2;, score=-6.564 total time=  14.3s
# [CV 1/5] END max_depth=10, min_samples_leaf=5, min_samples_split=10;, score=-1.513 total time=  13.7s
# [CV 2/5] END max_depth=10, min_samples_leaf=5, min_samples_split=10;, score=0.097 total time=  14.2s
# [CV 3/5] END max_depth=10, min_samples_leaf=5, min_samples_split=10;, score=-0.001 total time=  13.9s
# [CV 4/5] END max_depth=10, min_samples_leaf=5, min_samples_split=10;, score=0.110 total time=  14.5s
# [CV 5/5] END max_depth=10, min_samples_leaf=5, min_samples_split=10;, score=-6.564 total time=  14.4s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2;, score=0.124 total time=  28.2s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2;, score=0.136 total time=  28.7s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2;, score=0.001 total time=  30.9s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2;, score=0.161 total time=  32.5s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=2;, score=0.182 total time=  30.5s
# [CV 1/5] END max_depth=20, min_samples_leaf=1, min_samples_split=10;, score=0.120 total time=  29.3s
# [CV 2/5] END max_depth=20, min_samples_leaf=1, min_samples_split=10;, score=0.151 total time=  30.2s
# [CV 3/5] END max_depth=20, min_samples_leaf=1, min_samples_split=10;, score=0.001 total time=  31.4s
# [CV 4/5] END max_depth=20, min_samples_leaf=1, min_samples_split=10;, score=0.199 total time=  33.5s
# [CV 5/5] END max_depth=20, min_samples_leaf=1, min_samples_split=10;, score=0.195 total time=  29.9s
# [CV 1/5] END max_depth=20, min_samples_leaf=5, min_samples_split=2;, score=-1.591 total time=  14.4s
# [CV 2/5] END max_depth=20, min_samples_leaf=5, min_samples_split=2;, score=0.027 total time=  16.0s
# [CV 3/5] END max_depth=20, min_samples_leaf=5, min_samples_split=2;, score=-0.002 total time=  14.6s
# [CV 4/5] END max_depth=20, min_samples_leaf=5, min_samples_split=2;, score=0.093 total time=  15.3s
# [CV 5/5] END max_depth=20, min_samples_leaf=5, min_samples_split=2;, score=-6.668 total time=  15.2s
# [CV 1/5] END max_depth=20, min_samples_leaf=5, min_samples_split=10;, score=-1.591 total time=  14.3s
# [CV 2/5] END max_depth=20, min_samples_leaf=5, min_samples_split=10;, score=0.027 total time=  16.3s
# [CV 3/5] END max_depth=20, min_samples_leaf=5, min_samples_split=10;, score=-0.002 total time=  15.1s
# [CV 4/5] END max_depth=20, min_samples_leaf=5, min_samples_split=10;, score=0.093 total time=  15.8s
# [CV 5/5] END max_depth=20, min_samples_leaf=5, min_samples_split=10;, score=-6.668 total time=  13.7s
# Best parameters: {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 10}
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[14], line 29
#      26 model = DecisionTreeRegressor(**best_params, random_state=42)
#      28 # Make predictions
# ---> 29 y_pred = model.predict(X_test)
#      31 # Evaluate model
#      32 mae = mean_absolute_error(y_test, y_pred)
#
# File /opt/anaconda3/envs/tf2/lib/python3.8/site-packages/sklearn/tree/_classes.py:499, in BaseDecisionTree.predict(self, X, check_input)
#     476 def predict(self, X, check_input=True):
#     477     """Predict class or regression value for X.
#     478
#     479     For a classification model, the predicted class for each sample in X is
#    (...)
#     497         The predicted classes, or the predict values.
#     498     """
# --> 499     check_is_fitted(self)
#     500     X = self._validate_X_predict(X, check_input)
#     501     proba = self.tree_.predict(X)
#
# File /opt/anaconda3/envs/tf2/lib/python3.8/site-packages/sklearn/utils/validation.py:1461, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1458     raise TypeError("%s is not an estimator instance." % (estimator))
#    1460 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1461     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This DecisionTreeRegressor instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.

# %%
from sklearn.ensemble import RandomForestRegressor

# Hyperparameter tuning using GridSearchCV
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 10],
    'min_samples_split': [2, 10],
    'min_samples_leaf': [1, 5]
}

grid_search = GridSearchCV(
    RandomForestRegressor(random_state=42),
    param_grid,
    cv=5,
    scoring='r2',
    verbose=3  # Set verbosity to show progress
)
grid_search.fit(X_train, y_train)

# Best parameters
best_params = grid_search.best_params_
print(f"Best parameters: {best_params}")

# Train model with best parameters
model = RandomForestRegressor(**best_params, random_state=42)
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f'MAE: {mae}')
print(f'MSE: {mse}')
print(f'RMSE: {mse**0.5}')
print(f'R-squared: {r2}')
